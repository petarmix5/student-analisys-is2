# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_7c = pd.read_csv("C:\\Users\\AndreaHrelja\\Documents\\Faks\\IS2\\Završni\\Projekt\\data\\csv\\7c_2020-2021.csv")

# %%
df_7c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ucenik                        21 non-null     object
#  1   vladanje                      21 non-null     int64
#  2   broj_izostanaka               21 non-null     int64
#  3   bolest_lijecnicka_ispricnica  21 non-null     int64
#  4   bolest_opravdao_roditelj      21 non-null     int64
#  5   nastup                        21 non-null     int64
#  6   natjecanje                    21 non-null     int64
#  7   sportski_dopust               21 non-null     int64
#  8   srednja_ocjena                21 non-null     float64
#  9   opci_uspjeh                   21 non-null     float64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 1.8+ KB

# %%
df_7c.describe().transpose()
# Out:
#                               count       mean        std   min    25%    50%  \
# vladanje                       21.0   3.000000   0.547723  1.00   3.00   3.00
# broj_izostanaka                21.0  42.523810  48.184665  3.00  11.00  28.00
# bolest_lijecnicka_ispricnica   21.0  19.714286  34.479186  0.00   0.00   4.00
# bolest_opravdao_roditelj       21.0  12.380952  12.940155  0.00   0.00  12.00
# nastup                         21.0   0.047619   0.218218  0.00   0.00   0.00
# natjecanje                     21.0   1.142857   2.286607  0.00   0.00   0.00
# sportski_dopust                21.0   1.095238   3.604230  0.00   0.00   0.00
# srednja_ocjena                 21.0   4.020952   0.526563  2.71   3.69   4.07
# opci_uspjeh                    21.0   4.142857   0.478091  3.00   4.00   4.00
#
#                                 75%    max
# vladanje                       3.00    4.0
# broj_izostanaka               52.00  206.0
# bolest_lijecnicka_ispricnica  23.00  122.0
# ...

# %%
df_7c.nunique()
# Out:
# ucenik                          21
# vladanje                         3
# broj_izostanaka                 19
# bolest_lijecnicka_ispricnica    11
# bolest_opravdao_roditelj        12
# nastup                           2
# natjecanje                       4
# sportski_dopust                  4
# srednja_ocjena                  16
# opci_uspjeh                      3
# dtype: int64

# %%
df_7c.isnull().sum()
# Out:
# ucenik                          0
# vladanje                        0
# broj_izostanaka                 0
# bolest_lijecnicka_ispricnica    0
# bolest_opravdao_roditelj        0
# nastup                          0
# natjecanje                      0
# sportski_dopust                 0
# srednja_ocjena                  0
# opci_uspjeh                     0
# dtype: int64

# %%
# Correlation matrix

correlation_matrix = df_7c.corr()
sns.heatmap(correlation_matrix)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df_7c)

# %%
sns.relplot(x='vladanje', y='srednja_ocjena', hue='broj_izostanaka', data=df_7c)

# %%
sns.distplot(df_7c['srednja_ocjena'])
# Out:
# C:\Users\AndreaHrelja\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='srednja_ocjena', ylabel='Density'>

# %%
sns.distplot(df_7c['vladanje'])
# Out:
# C:\Users\AndreaHrelja\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='vladanje', ylabel='Density'>

# %%
sns.distplot(df_7c['broj_izostanaka'])
# Out:
# C:\Users\AndreaHrelja\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='broj_izostanaka', ylabel='Density'>

# %%
sns.catplot(x='broj_izostanaka', kind='box', data=df_7c)
